# %% [markdown]
# ### imports

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.io as pio
import re
import warnings
warnings.filterwarnings("ignore", 'This pattern has match groups')
pio.renderers.default = "notebook"
import panel as pn
pn.extension('plotly')

# %% [markdown]
# ## Summary
# - Three log files were given, and a templateList.csv
# - Each log file was about 1 Million Rows totalling 3.7 Million rows of logs
# - The data viz were chosen based on the business questions posed

# %% [markdown]
# # Table of contents
# 1. [How many of the 'TEMPLATE NAMES' occur in the log file?](#introduction)
#
# 2. [How many times does each TEMPLATE NAME occur in each log file?](#paragraph1)
#
#     1. [How many of the TEMPLATE NAMES do not occur even once in each log file?](#subparagraph1)
#
#
# 3. [How many of the TEMPLATE NAME occurrences are 'Invoice'?](#paragraph2)
#
#
# 4. [How many are 'PackSlip'?](#paragraph3)
#
#
# 5. [How many of the TEMPLATE NAME occurrences are 'Invoice'?](#paragraph4)

# %%
# preprocessing

def getTemplate(tf):
    '''returns a pandas dataframe 
    containing the desired template file
    from the root directory'''
    temp = pd.read_csv(tf)
    temp.columns = ['Names']
    mylist = []
    for name in temp.Names: mylist.append(name.rstrip('pp7')) # strip out file extensions
    temp.Names = mylist
    return temp

def outputStats(temp,i):
    '''prints some basic stuff'''
    count, mean, std, min,_,_,_,_ = temp[i].describe()
    print('Mean: '+ str(mean) + '\nStandard Deviation: '+ str(std))

def getLog(filename):
    '''returns a "cleanish" dataframe
    from the desired logfile'''
    s  = '-'*72
    with open(filename) as f:
        atext = f.read().split(s)
    df = pd.DataFrame(data = atext)
    df.columns = ['logs']
    return df

def getLogMatches(df, temp):
    '''returns a list of matches of each element of temp in df'''
    lis = []
    
    for col,row in temp.iterrows():
        filtereddf = df[df['logs'].str.contains(row['Names'])]
        lis.append(filtereddf.shape[0])
#     sortedtemp = temp.groupby(['log_matches'])
    return (lis)

# def matchBar(match, filename):
#     '''returns a plotly object'''
#     fig = go.Figure(
#         data=[go.Bar(y=match.log_matches.first(), x= match.Names.first())],
#         layout_title_text= 'By occurances in the log file: ' + filename
#     )
#     plotly_pane = pn.pane.Plotly(fig)
#     return plotly_pane

def matchBar(df, col):
    '''returns a plotly object'''
    fig = go.Figure(
        data=[go.Bar(y=df[col], x= df.Names)],
        layout_title_text= 'Number of occurances by TEMPLATE NAMES in the log file: ' + col
    )
    plotly_pane = pn.pane.Plotly(fig)
    return plotly_pane

# %%
filenames = ['ppw20210125.log', 'ppw20210126.log', 'ppw20210127.log']
temp = getTemplate('PP Templates (Initial) Listing.csv')
df1 = getLog(filenames[0])
df2 = getLog(filenames[1])
df3 = getLog(filenames[2])

# %%
temp[filenames[0]] = getLogMatches(df1, temp)
temp[filenames[1]] = getLogMatches(df2, temp)
temp[filenames[2]] = getLogMatches(df3, temp)

# %%
temp['total'] = temp[filenames].sum(axis=1)

# %%
temp = temp.sort_values(by='total')
temp
# Out:
#                                 Names  ppw20210125.log  ppw20210126.log  \
# 209           CompanyU_WO_GMP_Powder.                0                0
# 70       Company8_Statement_HP_P4515.                0                0
# 106            CompanyD_XML_PackSlip.                0                0
# 107                CompanyF_APCheque.                0                0
# 191   CompanyU_Invoice_NoDisc_HP4350.                0                0
# ..                                ...              ...              ...
# 210             CompanyU_XML_Invoice.              329              376
# 249  CompanyW_PickSlip_XML_HP_P4515x.              440              429
# 247            CompanyW_PickSlip_XML.              440              429
# 90         CompanyD_Invoice_HP_P4515.              530              452
# 255             CompanyW_XML_Invoice.             1065              665
#
#      ppw20210127.log  total
# 209                0      0
# 70                 0      0
# 106                0      0
# 107                0      0
# 191                0      0
# ..               ...    ...
# 210              263    968
# 249              407   1276
# 247              407   1276
# 90               331   1313
# 255              423   2153
#
# [419 rows x 5 columns]

# %% [markdown]
# <a name="introduction"></a>
# ## How many of the 'TEMPLATE NAMES' occur in the log file?

# %%
for i in range(0,3):
    outputStats(temp,filenames[i])
    display(matchBar(temp.sort_values(by=filenames[i]).tail(30), filenames[i]))
# Out:
# Mean: 11.334128878281623
# Standard Deviation: 71.80654536207007
# Plotly(Figure)
# Mean: 11.062052505966587
# Standard Deviation: 59.30987449021523
# Plotly(Figure)
# Mean: 9.073985680190932
# Standard Deviation: 46.361712529001814
# Plotly(Figure)

# %% [markdown]
# <a name="paragraph1"></a>
# ## How many times does each TEMPLATE NAME occur in each log file?

# %%
def stackedBar(temp,filenames):
    temp = temp.tail(50)
    x = temp['Names']

    fig = go.Figure(data=[go.Bar(
        name = filenames[0],
        x = x,
        y = temp[filenames[0]]
       ),
                go.Bar(
        name = filenames[1],
        x = x,
        y = temp[filenames[1]]
       ),
                 go.Bar(
        name = filenames[2],
        x = x,
        y = temp[filenames[2]]
       )
    ])
    
#     fig.update_layout(barmode = 'stack')
    plotly_pane = pn.pane.Plotly(fig)
    return plotly_pane

display(stackedBar(temp,filenames))
# Out:
# Plotly(Figure)

# %% [markdown]
# <a name="subparagraph1"></a>
# ### How many of the TEMPLATE NAMES do not occur even once in each log file?

# %%
print('These Template Names do not occur even once in ANY of the the log files: ')



temp[temp['total']==0]['Names'].sort_values().values
# Out:
# These Template Names do not occur even once in ANY of the the log files:
# array(['AND_DBA_Invoice_C5051.', 'AND_DBA_Invoice_HPM605.',
#        'AND_DBA_Invoice_HP_P3015.', 'AND_DBA_Invoice_New.',
#        'AND_DBA_Invoice_Orig.', 'AND_DBA_PO.', 'AND_DBA_PackSlip_HPM605.',
#        'AND_DBA_PickSlipApproved_HP_P4515.', 'AND_DBA_PickSlip_HPM605.',
#        'AND_DBA_Statement.', 'AND_DBA_Statement_080219.',
#        'AND_DBA_Statement_HP_P3015.',
#        'AND_DBA_Statement_MANUAL_NOTICE_02.', 'AND_DBA_Statement_Orig.',
#        'AND_DBA_XML_Invoice.', 'AND_DBA_XML_Invoice_HP.',
#        'AND_DBA_XML_Invoice_HPM605.', 'AND_DBA_XML_Invoice_Mail.',
#        'AND_DBA_XML_PackSlip.', 'AND_DBA_XML_PackSlip_HP.',
#        'AND_DBA_XML_PackSlip_HPM605.', 'AND_Invoice.',
#        'AND_Invoice_4235.', 'AND_Invoice_C5051.', 'AND_Invoice_Faxing.',
#        'AND_PO.', 'AND_PackSlip.', 'AND_PackSlip_4235.', 'AND_PickSlip.',
#        'AND_PickSlip_4235.', 'AON_PO.', 'CaptureTest.',
#        'Company0_Statement.', 'Company2M_Invoice.', 'Company2M_PackSlip.',
#        'Company2M_PickSlip.', 'Company2M_Statement_HP_P4515.',
#        'Company2_APCheque.', 'Company2_DirectDeposit.',
#        'Company2_DirectDeposit_(Update_Color).',
#        'Company2_DirectDeposit_03JAN19.', 'Company2_Invoice_HP2430.',
#        'Company2_Invoice_HP4350.', 'Company2_Invoice_HP_P4515.',
#        'Company2_MIL_DOOR_HP_P3015.', 'Company2_MIL_HP_P3015.',
#        'Company2_MIL_HP_P3015_022019.', 'Company2_MIL_SKID_HP_P3015.',
#        'Company2_PO_Faxing.', 'Company2_PO_HP_P3015_060419.',
#        'Company2_PickSlip_HP_P4515.', 'Company3_Invoice_C5051.',
#        'Company3_Invoice_HP2430.', 'Company3_PickSlip.',
#        'Company8_PackSlip_HP_P4515.', 'Company8_PickSlip_HP_P4515.',
#        'Company8_Statement_HP_P4515.', 'CompanyC_Invoice_Canon.',
#        'CompanyC_Invoice_Faxing.', 'CompanyC_Invoice_FileMail_HP_P4515.',
#        'CompanyC_Invoice_HP4350.', 'CompanyC_Statement_HP_P4515.',
#        'CompanyDBranch5_Invoice_C5051.',
#        'CompanyDBranch5_Invoice_Faxing.',
#        'CompanyDBranch5_Invoice_FileMail_HP_P4515.',
#        'CompanyDBranch5_Invoice_HP_P4515.',
#        'CompanyDBranch5_PackSlip_HP_P4515.',
#        'CompanyDBranch5_PickSlip_HPM605.',
#        'CompanyDBranch5_PickSlip_HP_P4515.',
#        'CompanyDBranch5_Statement_HP_P4515.',
#        'CompanyDBranch5_XML_Invoice.', 'CompanyD_APCheque.',
#        'CompanyD_Invoice_C5051.', 'CompanyD_Invoice_HP2430.',
#        'CompanyD_Invoice_HP_P4515_Orig.', 'CompanyD_OrderEmail.',
#        'CompanyD_PO.', 'CompanyD_PickSlipApproved_HP_P4515.',
#        'CompanyD_PickSlip_Store_HPM605.',
#        'CompanyD_PickSlip_Store_HP_P4515.', 'CompanyD_Quote.',
#        'CompanyD_Statement_HP_P4515.', 'CompanyD_TestCheque.',
#        'CompanyD_XML_Invoice.', 'CompanyD_XML_PackSlip.',
#        'CompanyF_APCheque.', 'CompanyF_Invoice.',
#        'CompanyF_Invoice_02252020.', 'CompanyF_PO.', 'CompanyF_PickSlip.',
#        'CompanyG_BlanketContract.', 'CompanyG_GoodsInspection.',
#        'CompanyG_PO_HP_P3015New_04162019.',
#        'CompanyG_PO_HP_P3015New_060419.', 'CompanyG_PO_HP_P3015_KL.',
#        'CompanyG_PO_HP_P3015_MK.', 'CompanyG_PO_Inovo.', 'CompanyG_PR.',
#        'CompanyG_PR_Foreign.', 'CompanyG_PR_HP_P3015New.',
#        'CompanyG_PR_Inovo.', 'CompanyG_PickSlip.',
#        'CompanyG_PickSlipApproved_HP_P4515.',
#        'CompanyG_PickSlip_HP_P4515.', 'CompanyG_Statement_HP_P4515.',
#        'CompanyG_WO61_DAD.', 'CompanyG_WOSKID61_HP_M602.',
#        'CompanyG_WOSKID61_HP_P4515_03162020.',
#        'CompanyG_WO_GMP_HP_P4515.', 'CompanyG_WO_GMP_HP_P4515_061119.',
#        'CompanyG_WO_GMP_Powder_HP_P4515.', 'CompanyG_WO_StabReqForm.',
#        'CompanyM_Invoice_C5051.', 'CompanyM_Invoice_HP4350.',
#        'CompanyM_PO.', 'CompanyM_PickSlip_C5051.',
#        'CompanyM_PickSlip_HP_P4515.', 'CompanyN_APCheque.',
#        'CompanyO_Invoice.', 'CompanyO_PackSlip.', 'CompanyT_APCheque.',
#        'CompanyU61_WOSKID.', 'CompanyUBranch5_Invoice_C5051.',
#        'CompanyUBranch5_Invoice_Faxing.',
#        'CompanyUBranch5_Invoice_MailFile_HP_P4515.',
#        'CompanyUBranch5_PackSlip_HP4350.',
#        'CompanyUBranch5_PickSlipTracking_HP_P4515.',
#        'CompanyUBranch5_PickSlip_HP_P4515.',
#        'CompanyUBranch5_Statement_HP_P4515.',
#        'CompanyUBranch5_XML_Invoice_HP4350_bak.',
#        'CompanyUBranch5_XML_Invoice_bak.', 'CompanyU_APCheque.',
#        'CompanyU_DirectDeposit.',
#        'CompanyU_DirectDeposit_(Update_Color).',
#        'CompanyU_DirectDeposit_Old.', 'CompanyU_Invoice_DAD.',
#        'CompanyU_Invoice_EmailExec.', 'CompanyU_Invoice_HP4050_04082019.',
#        'CompanyU_Invoice_HP4050_103119.',
#        'CompanyU_Invoice_HP4350_02142019.', 'CompanyU_Invoice_HP8150.',
#        'CompanyU_Invoice_MailFile_HP_P4515.',
#        'CompanyU_Invoice_NoDisc_04082019.',
#        'CompanyU_Invoice_NoDisc_Faxing.',
#        'CompanyU_Invoice_NoDisc_HP4350.',
#        'CompanyU_Invoice_NoDisc_HP4515.',
#        'CompanyU_Invoice_NoDisc_ST_HP4515.',
#        'CompanyU_Invoice_STRX_HP_P4515.', 'CompanyU_PO_Faxing.',
#        'CompanyU_PO_HP_P3015.', 'CompanyU_PackSlip_HP8150.',
#        'CompanyU_PackSlip_ST_HP_P4515.',
#        'CompanyU_PickSlipApproved_HP_P4515.',
#        'CompanyU_PickSlipExport_HP_P4515.',
#        'CompanyU_PickSlipTacking_HP_P4515.',
#        'CompanyU_PickSlip_HP_P4515.', 'CompanyU_Statement_HP_P4515.',
#        'CompanyU_WO61.', 'CompanyU_WO_GMP.', 'CompanyU_WO_GMP_Powder.',
#        'CompanyU_XML_Invoice_102419.', 'CompanyU_XML_Invoice_103119.',
#        'CompanyU_XML_Invoice_HP4350_bak.',
#        'CompanyU_XML_Invoice_NoDisc_HP4350_bak.',
#        'CompanyU_XML_Invoice_NoDisc_bak.', 'CompanyU_XML_Invoice_bak.',
#        'CompanyW_APCheque.', 'CompanyW_APChequeCOPY.',
#        'CompanyW_Invoice_M600_HP_8150.', 'CompanyW_Invoice_M608.',
#        'CompanyW_PackSlip_CanoniR4035.', 'CompanyW_PackSlip_HP_P3015.',
#        'CompanyW_PackSlip_HP_P4515.', 'CompanyW_PackSlip_M600_HP_8150.',
#        'CompanyW_PackSlip_M600_Tray4.', 'CompanyW_PackSlip_M608.',
#        'CompanyW_PickSlipApproved_HP_P4515.',
#        'CompanyW_PickSlip_Canon4225_11222018.',
#        'CompanyW_PickSlip_CanoniR4035.',
#        'CompanyW_PickSlip_CanoniR4035_11202018.',
#        'CompanyW_PickSlip_HP_P4515x_11202018.',
#        'CompanyW_PickSlip_HP_P4515x_2.',
#        'CompanyW_PickSlip_M600_01162019.',
#        'CompanyW_PickSlip_M600_11202018.', 'CompanyW_PickSlip_M600_2.',
#        'CompanyW_PickSlip_XML_11202018.',
#        'CompanyW_PickSlip_XML_HP_P4515x_11202018.', 'CompanyW_Reimburse.',
#        'CompanyW_Statement_HP_P4515.', 'CompanyW_XML_PackSlip_1505.',
#        'CompanyW_XML_PackSlip_Tray4.', 'CompanyX_APCheque.',
#        'CompanyX_Invoice_Canon.', 'CompanyX_Invoice_Faxing.',
#        'CompanyX_Invoice_FileMail_HP_P4515.',
#        'CompanyX_Invoice_HP_P4515.', 'CompanyX_PO.',
#        'CompanyX_PackSlip_HP_P4515.', 'CompanyX_PickSlip_HP_P4515.',
#        'CompanyX_PickSlip_HP_P4515_11202018.', 'CompanyX_PickSlip_XML.',
#        'CompanyX_PickSlip_XML_11202018.', 'CompanyX_PickSlip_XML_M608.',
#        'CompanyX_PickSlip_XML_copy.', 'CompanyX_Statement_HP_P4515.',
#        'CompanyZBranch5_Invoice_A4_090419.',
#        'CompanyZBranch5_Invoice_A4_Fuji.', 'CompanyZBranch5_PackSlip.',
#        'CompanyZBranch5_PackSlip_A4.', 'CompanyZBranch5_PickSlip.',
#        'CompanyZBranch5_PickSlip_A5.', 'CompanyZBranch5_Statement.',
#        'CompanyZBranch5_Statement_03282019.',
#        'CompanyZBranch5_Statement_A4.', 'CompanyZ_Invoice_A4_032119.',
#        'CompanyZ_Invoice_A4_032719.', 'CompanyZ_Invoice_A4_Fuji.',
#        'CompanyZ_Invoice_HP_P4515.', 'CompanyZ_Invoice_HP_P4515_040418.',
#        'CompanyZ_PO_040418.', 'CompanyZ_PackSlip_A4_032119.',
#        'CompanyZ_PackSlip_A4_Fuji.', 'CompanyZ_PackSlip_HP_P4515.',
#        'CompanyZ_PickSlip_A4_032119.', 'CompanyZ_PickSlip_A4_090619.',
#        'CompanyZ_PickSlip_A4_C3300_032119.', 'CompanyZ_PickSlip_A4_Fuji.',
#        'CompanyZ_PickSlip_HP_P4515-(230318).',
#        'CompanyZ_PickSlip_HP_P4515.', 'CompanyZ_PurchaseOrder.',
#        'CompanyZ_Statement_A4_Canon_C4225.',
#        'CompanyZ_Statement_Canon_C4225.', 'CompanyZ_Statement_HP_P4515.',
#        'CompanyZ_Statement_HP_P4515_040418.', 'CompanyZ_WO.',
#        'CompanyZ_WOSKID.', 'CompanyZ_WOSKID_A4.', 'CompanyZ_WO_040418.',
#        'CompanyZ_WO_A4.', 'CompanyZ_WO_GMP.', 'CompanyZ_WO_GMP_A4.',
#        'CompanyZ_WO_GMP_Powder.', 'CompanyZ_WO_GMP_Powder_A4.',
#        'Mettler_ReportTxt_(Orig).', 'NFQC_0001.', 'NFQC_0004.',
#        'NFQC_0005.', 'NFQC_0013.', 'NFQC_0026.', 'NFQC_0032.',
#        'NFQC_0037.', 'NFQC_0038.', 'NFQC_0040.', 'NFQC_0041.',
#        'NFQC_0042.', 'NFQC_0051.', 'NFQC_0060.', 'NFQC_0099.',
#        'NFQC_0102.', 'NFQC_0107.', 'NFQC_0133.', 'NFQC_0134.',
#        'NFQC_0135.', 'QCWP085.', 'Remittance.', 'SOP-PF-TAB-NF0054T-200.',
#        'SOP-PF-TAB.', 'SOP-PF-TABT.', 'SOP-PF-TBLN-NF0054T-200.',
#        'SOP-PF-TBLN-NF1248T-100.', 'SOP-PF-TBLN-NF1248T-200.',
#        'SOP-PF-TBLN-NF1248T-300.', 'SOP-PF-TBLN.',
#        'SOP-PF-TTAB-NF0054T-200.', 'SOP-TheHongTest.', 'SOP-WO.',
#        'SOP_2_MIL.', 'SOP_2_MIL_DOOR_HP_P3015.', 'SOP_2_MIL_SKID.',
#        'SOP_2_MIL_TAB_NF0390T.', 'SOP_2_MIL_TAB_NF1248T.',
#        'SOP_2_MIL_TBLN_NF0390T.', 'SOP_2_MIL_TBLN_NF1248T.',
#        'SOP_2_WOSKID.', 'SOP_2_WO_FGSW.', 'SOP_2_WO_GMP.',
#        'SOP_2_WO_PCRD.', 'SOP_2_WO_PIFC.', 'SOP_2_WO_PIFC_2.',
#        'SOP_2_WO_PSWR.', 'SOP_2_WO_PTRY.', 'StoreBarCodes.',
#        'StorePrices.', 'TEST_SALMANpp7.', 'TPM_0_Invoice.',
#        'TPM_D_Invoice.', 'TPM_D_PackSlip.', 'TPM_N_Invoice.',
#        'TPM_N_PackSlip.', 'TPM_U_Invoice.', 'TPM_U_PackSlip.',
#        'TPM_W_Invoice.', 'TPM_W_PackSlip.', 'TPM_X_Invoice.',
#        'TPM_X_PackSlip.', 'TPM_Z_Invoice.', 'TPM_Z_PackSlip.',
#        'USP_1119.', 'WMS_Bulk_CBLN.', 'WMS_Bulk_NF0054T.',
#        'WMS_Bulk_NF0285T.', 'WMS_Bulk_NF0390T.', 'WMS_Bulk_NF0392T.',
#        'WMS_Bulk_NF0411T.', 'WMS_Bulk_NF0666T.', 'WMS_Bulk_NF0693T.',
#        'WMS_Bulk_NF0971T.', 'WMS_Bulk_NF1248T.',
#        'WMS_Bulk_NF1248T_021519.', 'WMS_Bulk_NF1248T_0222019.',
#        'WMS_Bulk_NF1854C.', 'WMS_Bulk_NF2416T.', 'WMS_Bulk_WN3314BK.',
#        'XML_DBranch5_Invoice.', 'XML_D_Invoice.', 'XML_D_PackSlip.',
#        'XML_N_Invoice.', 'XML_N_PackSlip.', 'XML_UBranch5_Invoice.',
#        'XML_UBranch5_PackSlip.', 'XML_U_Invoice.',
#        'XML_U_NoDisc_Invoice.', 'XML_U_PackSlip.', 'XML_W_Invoice.',
#        'XML_W_PackSlip.', 'XML_X_Invoice.', 'XML_X_PackSlip.'],
#       dtype=object)

# %%
# fig = px.sunburst(temp, path=['type'], values='total')
# plotly_pane = pn.pane.Plotly(fig)
# print('Number of occurences by type')
# display(plotly_pane)

# temp[temp['total']==0]['Names'].count()
fig = px.pie(temp, values = 'totals')
# Out:
# 337

# %%
# Find the percentage of zero vs. non-zero templates
# Group the percentage of zero templates by their type

x = ['No occurance', 'One or more occurances']

# fig.update_layout(barmode='stack')
plotly_pane = pn.pane.Plotly(fig)
display(plotly_pane)
# Out:
#   File "<ipython-input-10-2e0ed625f2d5>", line 10
#     ),
#     ^
# SyntaxError: invalid syntax

# %%
# temp.Names.str.contains('Invoice').value_counts()
temp['Invoice'] = temp.Names.str.contains('Invoice')
temp['Packslip'] = temp.Names.str.contains('PackSlip')
temp['Pickslip'] = temp.Names.str.contains('PickSlip')
# temp.loc[~temp['Names'].str.contains('Invoice|Pack|Pick', flags = re.I, regex = True)]
temp['Other'] = ~temp['Names'].str.contains('Invoice|Pack|Pick', flags = re.I, regex = True)

# %%
temp['Invoice'] = temp.Invoice.map({True: 'Invoice', False: ''})
temp['Packslip'] = temp.Packslip.map({True: 'Packslip', False: ''})
temp['Pickslip'] = temp.Pickslip.map({True: 'Pickslip', False: ''})
temp['Other'] = temp.Other.map({True: 'Other', False: ''})

# %%
temp['type'] = (temp['Invoice'] + temp['Packslip']+ temp['Pickslip']+ temp['Other']).astype(str)
# Out:
# Other       185
# Invoice     121
# Pickslip     63
# Packslip     50
# Name: type, dtype: int64

# %%
temp = temp.drop(['Invoice','Packslip','Pickslip','Other'], axis = 1)
temp
# Out:
#                                 Names  ppw20210125.log  ppw20210126.log  \
# 209           CompanyU_WO_GMP_Powder.                0                0
# 70       Company8_Statement_HP_P4515.                0                0
# 106            CompanyD_XML_PackSlip.                0                0
# 107                CompanyF_APCheque.                0                0
# 191   CompanyU_Invoice_NoDisc_HP4350.                0                0
# ..                                ...              ...              ...
# 210             CompanyU_XML_Invoice.              329              376
# 249  CompanyW_PickSlip_XML_HP_P4515x.              440              429
# 247            CompanyW_PickSlip_XML.              440              429
# 90         CompanyD_Invoice_HP_P4515.              530              452
# 255             CompanyW_XML_Invoice.             1065              665
#
#      ppw20210127.log  total      type
# 209                0      0     Other
# 70                 0      0     Other
# 106                0      0  Packslip
# 107                0      0     Other
# 191                0      0   Invoice
# ..               ...    ...       ...
# 210              263    968   Invoice
# 249              407   1276  Pickslip
# 247              407   1276  Pickslip
# 90               331   1313   Invoice
# 255              423   2153   Invoice
#
# [419 rows x 6 columns]

# %% [markdown]
# <a name="paragraph2"></a>
# ## How many of the TEMPLATE NAME occurrences are 'Invoice'?

# %% [markdown]
# <a name="paragraph3"></a>
# ## How many are 'PackSlip'?

# %% [markdown]
# <a name="paragraph4"></a>
# ## How many are PickSlip'?

# %%
#find the percentage for this graph
temp['total']
# Out:
# 209       0
# 70        0
# 106       0
# 107       0
# 191       0
#        ...
# 210     968
# 249    1276
# 247    1276
# 90     1313
# 255    2153
# Name: total, Length: 419, dtype: int64

# %%
fig = px.sunburst(temp, path=['type'], values='total')
plotly_pane = pn.pane.Plotly(fig)
print('Number of occurences by type')
display(plotly_pane)
print(temp['total'].value_counts(normalize=True))
# Out:
# Number of occurences by type
# Plotly(Figure)
# 0       0.804296
# 2       0.021480
# 6       0.011933
# 7       0.011933
# 1       0.011933
# 12      0.009547
# 18      0.009547
# 11      0.007160
# 15      0.007160
# 20      0.004773
# 19      0.004773
# 14      0.004773
# 298     0.004773
# 8       0.004773
# 31      0.004773
# 1276    0.004773
# 4       0.004773
# 286     0.004773
# 3       0.002387
# 13      0.002387
# 5       0.002387
# 21      0.002387
# 26      0.002387
# 968     0.002387
# 34      0.002387
# 424     0.002387
# 931     0.002387
# 293     0.002387
# 1313    0.002387
# 283     0.002387
# 196     0.002387
# 106     0.002387
# 2153    0.002387
# 599     0.002387
# 85      0.002387
# 84      0.002387
# 76      0.002387
# 72      0.002387
# 61      0.002387
# 57      0.002387
# 560     0.002387
# 40      0.002387
# 550     0.002387
# 35      0.002387
# Name: total, dtype: float64
